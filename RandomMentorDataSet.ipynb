# %%
import numpy as np
import pandas as pd

# Öğrenci sayısı
mentor_num = 70

Graduate=['Master Degree', 'PhD Candidate', 'Postdoctoral Researcher']
# Okul yılları
mentor_degree = np.random.choice(Graduate, size=mentor_num)

# Okul bağlantıları
affiliations = np.random.choice([
    "Boğaziçi University",
    "Gazi University",
    "ODTU",
    "ITU",
    "Hacettepe University",
    "Gebze Technical University",
    "İzmir Yüksek Teknoloji Üniversitesi",
    "Harran Üniversitesi",
    "Balikesir Üniversitesi",
    "Bursa Teknik Üniversitesi",
    "Uludağ Üniversitesi",
    "Bilkent Üniversitesi",
    "Koç Üniversitesi",
    "Sabanci Üniversitesi",
    "Pennsylvania State University",
    "University of Leeds",
    "University of Southern California",
    "McMaster University",
    "MSGSÜ",
    "Özyeğin Üniversitesi",
    "Faculty of Engineering  - Nahda University",
    "University of Bristol and University of Neuchatel",
    "University of Amsterdam",
    "University of Zurich, Institute of Mathematics",
    "University of Arizona",
    "Technische Universität Berlin",
    "University of Toledo",
    "The University of Chicago",
    "Wesleyan University",
    "University of Georgia",
    "Ankara Hac Bayram Veli University",
    "Penn State"
], size=mentor_num)

# İlgi alanları
interests = np.random.choice(["Quantum Theory",
    "Complex Systems/Dynamical Systems",
    "Analysis",
    "Topology",
    "Algebra",
    "Partial Differential Equations",
    "Cryptography/Coding theory",
    "Probability Theory",
    "Complex Analysis",
    "Real Analysis/Functional Analysis",
    "Algebraic Number Theory",
    "Classical Mechanics",
    "Fluid Dynamics",
    "Hydrodynamic Instability",
    "Mathematical Modeling",
    "Data Science",
    "Statistics",
    "Differantial Geometry",
    "Numerical Analysis"]
    +
    [
    "Quantum Theory",
    "Complex Systems/Dynamical Systems",
    "Analysis",
    "Topology",
    "Algebra",
    "Partial Differential Equations",
    "Cryptography/Coding theory",
    "Probability Theory",
    "Complex Analysis",
    "Real Analysis/Functional Analysis",
    "Algebraic Number Theory",
    "Classical Mechanics",
    "Fluid Dynamics",
    "Hydrodynamic Instability",
    "Mathematical Modeling",
    "Data Science",
    "Statistics",
    "Differantial Geometry",
    "Numerical Analysis"
], size=mentor_num)

# Cinsiyet
genders = np.random.choice(["Kadin", "Erkek"], size=mentor_num)


data = pd.DataFrame({
    "School year": mentor_degree,
    "Affiliation": affiliations,
    "Branches of Interest": interests,
    "Cinsiyet": genders
})

# Veriyi CSV dosyası olarak kaydet
data.to_csv("randommentordataset.csv", index=False)
