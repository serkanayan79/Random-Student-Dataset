# %% [markdown]
# <a href="https://colab.research.google.com/github/serkanayan79/Random-Student-Dataset/blob/PandasTakingNotes/Pandas_Taking_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('Test data - Students.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of          Name  Gender   University                          Department Class  \
# 0    Student1    Male      Bilkent                         Mathematics     1
# 1    Student2    Male         ODTU                         Mathematics     3
# 2    Student3    Male         ODTU                         Mathematics     4
# 3    Student4    Male     Bogazici                         Mathematics     1
# 4    Student5    Male         ODTU                         Mathematics     4
# ..        ...     ...          ...                                 ...   ...
# 85  Student86  Female        Bilgi                         Mathematics     2
# 86  Student87    Male         ODTU  Computer Engineering & Mathematics     3
# 87  Student88    Male         ODTU                         Mathematics     4
# 88  Student89  Female  Galatasaray                         Mathematics     2
# 89  Student90  Female          GTU                         Mathematics     4
#
# ...

# %%
# df.columns

# for index, row in df.iterrows():
#   print(index, row['Class'])

# df.loc[df['Which of the following topic(s) would you be most interested in reading about? [Set Theory/Model Theory]']=="First Choice"]
# Out:
#          Name  Gender University   Department Class  \
# 1    Student2    Male       ODTU  Mathematics     3
# 6    Student7    Male   Bogazici  Mathematics     2
# 10  Student11    Male   Bogazici  Mathematics     3
# 34  Student35    Male      Bilgi  Mathematics    5+
# 36  Student37  Female       ODTU  Mathematics     4
# 39  Student40    Male     Ankara  Mathematics     1
# 63  Student64  Female       ODTU  Mathematics     3
# 85  Student86  Female      Bilgi  Mathematics     2
# 87  Student88    Male       ODTU  Mathematics     4
#
#    Which of the following topic(s) would you be most interested in reading about? [Set Theory/Model Theory]  \
# 1                                        First Choice
# 6                                        First Choice
# 10                                       First Choice
# 34                                       First Choice
# 36                                       First Choice
# 39                                       First Choice
# ...

# %%
# a=df.sort_values(['Class', 'Which of the following topic(s) would you be most interested in reading about? [Set Theory/Model Theory]'], ascending=False)

# %%
# print(a.head(8))
# Out:
#          Name                 Gender University  \
# 67  Student68                 Female       ODTU
# 34  Student35                   Male      Bilgi
# 26  Student27                   Male   Bogazici
# 32  Student33  Prefer not to respond      MSGSU
# 35  Student36                 Female        GTU
# 61  Student62                   Male      MSGSU
# 64  Student65                   Male       ODTU
# 70  Student71                 Female       ODTU
#
#                             Department Class  \
# 67                         Mathematics    5+
# 34                         Mathematics    5+
# 26  Computer Engineering & Mathematics    5+
# 32                         Mathematics    5+
# 35                         Mathematics    5+
# 61            Statistics & Mathematics    5+
# 64                             Physics    5+
# 70                             Physics    5+
#
#    Which of the following topic(s) would you be most interested in reading about? [Set Theory/Model Theory]  \
# ...

# %%
df.loc[(df['Class'] == '2' or df['Name'] == 'Student3')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-75b119859184> in <cell line: 1>()
# ----> 1 df.loc[(df['Class'] == '2' or df['Name'] == 'Student3')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
